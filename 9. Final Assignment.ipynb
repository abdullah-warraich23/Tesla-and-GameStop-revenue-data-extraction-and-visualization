# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0220ENSkillsNetwork900-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# <h1>Extracting and Visualizing Stock Data</h1>
# <h2>Description</h2>

# %% [markdown]
# Extracting essential data from a dataset and displaying it is a necessary part of data science; therefore individuals can make correct decisions based on the data. In this assignment, you will extract some stock data, you will then display this data in a graph.

# %% [markdown]
# <h2>Table of Contents</h2>
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ul>
#         <li>Define a Function that Makes a Graph</li>
#         <li>Question 1: Use yfinance to Extract Stock Data</li>
#         <li>Question 2: Use Webscraping to Extract Tesla Revenue Data</li>
#         <li>Question 3: Use yfinance to Extract Stock Data</li>
#         <li>Question 4: Use Webscraping to Extract GME Revenue Data</li>
#         <li>Question 5: Plot Tesla Stock Graph</li>
#         <li>Question 6: Plot GameStop Stock Graph</li>
#     </ul>
# <p>
#     Estimated Time Needed: <strong>30 min</strong></p>
# </div>
#
# <hr>

# %%
# !pip install yfinance==0.1.70
# !mamba install --upgrade bs4==4.10.0 

# !pip install --upgrade nbformat --user
# Out:
# Requirement already satisfied: yfinance==0.1.70 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (0.1.70)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from yfinance==0.1.70) (1.4.1)
# Requirement already satisfied: requests>=2.26 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from yfinance==0.1.70) (2.28.2)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from yfinance==0.1.70) (0.0.11)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from yfinance==0.1.70) (4.9.1)
# Requirement already satisfied: numpy>=1.15 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from yfinance==0.1.70) (1.22.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.24.0->yfinance==0.1.70) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.24.0->yfinance==0.1.70) (2022.7.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26->yfinance==0.1.70) (2021.10.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26->yfinance==0.1.70) (2.0.10)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26->yfinance==0.1.70) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26->yfinance==0.1.70) (1.26.8)
# Requirement already satisfied: six>=1.5 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.24.0->yfinance==0.1.70) (1.16.0)
# usage: mamba [-h] [--version] [--slow SLOW] [--enable-coverage]
#              [--coverage-file COVERAGE_FILE] [--format FORMAT] [--no-color]
#              [--tags TAGS]
#              [specs ...]
# mamba: error: unrecognized arguments: --upgrade bs4==4.10.0
# Requirement already satisfied: nbformat in c:\users\abdullah.warraich\appdata\roaming\python\python310\site-packages (5.7.3)
# Requirement already satisfied: fastjsonschema in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from nbformat) (2.16.2)
# Requirement already satisfied: traitlets>=5.1 in c:\users\abdullah.warraich\appdata\roaming\python\python310\site-packages (from nbformat) (5.4.0)
# Requirement already satisfied: jupyter-core in c:\users\abdullah.warraich\appdata\roaming\python\python310\site-packages (from nbformat) (4.11.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from nbformat) (4.17.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat) (0.19.3)
# Requirement already satisfied: pywin32>=1.0 in c:\users\abdullah.warraich\appdata\roaming\python\python310\site-packages (from jupyter-core->nbformat) (304)
# Requirement already satisfied: pandas==1.4.1 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (1.4.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from pandas==1.4.1) (1.22.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from pandas==1.4.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from pandas==1.4.1) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas==1.4.1) (1.16.0)

# %%
pd.__version__

#!pip install pandas==1.4.1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 pd.__version__
#
# NameError: name 'pd' is not defined

# %%
import yfinance as yf
import pandas as pd
import requests
from bs4 import BeautifulSoup
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %% [markdown]
# ## Define Graphing Function

# %% [markdown]
# In this section, we define the function `make_graph`. You don't have to know how the function works, you should only care about the inputs. It takes a dataframe with stock data (dataframe must contain Date and Close columns), a dataframe with revenue data (dataframe must contain Date and Revenue columns), and the name of the stock.

# %%
def make_graph(stock_data, revenue_data, stock):
    fig = make_subplots(rows=2, cols=1, shared_xaxes=True, subplot_titles=("Historical Share Price", "Historical Revenue"), vertical_spacing = .3)
    stock_data_specific = stock_data[stock_data.Date <= '2021--06-14']
    revenue_data_specific = revenue_data[revenue_data.Date <= '2021-04-30']
    fig.add_trace(go.Scatter(x=pd.to_datetime(stock_data_specific.Date, infer_datetime_format=True), y=stock_data_specific.Close.astype("float"), name="Share Price"), row=1, col=1)
    fig.add_trace(go.Scatter(x=pd.to_datetime(revenue_data_specific.Date, infer_datetime_format=True), y=revenue_data_specific.Revenue.astype("float"), name="Revenue"), row=2, col=1)
    fig.update_xaxes(title_text="Date", row=1, col=1)
    fig.update_xaxes(title_text="Date", row=2, col=1)
    fig.update_yaxes(title_text="Price ($US)", row=1, col=1)
    fig.update_yaxes(title_text="Revenue ($US Millions)", row=2, col=1)
    fig.update_layout(showlegend=False,
    height=900,
    title=stock,
    xaxis_rangeslider_visible=True)
    fig.show()

# %% [markdown]
# ## Question 1: Use yfinance to Extract Stock Data

# %% [markdown]
# Using the `Ticker` function enter the ticker symbol of the stock we want to extract data on to create a ticker object. The stock is Tesla and its ticker symbol is `TSLA`.

# %%
tesla_ticker=yf.Ticker("TSLA")

# %% [markdown]
# Using the ticker object and the function `history` extract stock information and save it in a dataframe named `tesla_data`. Set the `period` parameter to `max` so we get information for the maximum amount of time.

# %%
# !pip install -U yfinance pandas
# Out:
# Requirement already satisfied: yfinance in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (0.1.70)
# Collecting yfinance
#   Using cached yfinance-0.2.10-py2.py3-none-any.whl (59 kB)
# Requirement already satisfied: pandas in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (1.4.1)
# Collecting pandas
#   Using cached pandas-1.5.3-cp310-cp310-win_amd64.whl (10.4 MB)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (2.3.4)
# Requirement already satisfied: html5lib>=1.1 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (4.11.2)
# Requirement already satisfied: requests>=2.26 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (2.28.2)
# Requirement already satisfied: cryptography>=3.3.2 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (36.0.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (1.22.0)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: cffi>=1.12 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from cryptography>=3.3.2->yfinance) (1.15.0)
# Requirement already satisfied: six>=1.9 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26->yfinance) (2.0.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26->yfinance) (1.26.8)
# Requirement already satisfied: pycparser in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# Installing collected packages: pandas, yfinance
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.4.1
#     Uninstalling pandas-1.4.1:
#       Successfully uninstalled pandas-1.4.1
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.1.70
#     Uninstalling yfinance-0.1.70:
#       Successfully uninstalled yfinance-0.1.70
# Successfully installed pandas-1.5.3 yfinance-0.2.10

# %%
tesla_data = tesla_ticker.history(period="1y")

# %% [markdown]
# **Reset the index** using the `reset_index(inplace=True)` function on the tesla_data DataFrame and display the first five rows of the `tesla_data` dataframe using the `head` function. Take a screenshot of the results and code from the beginning of Question 1 to the results below.

# %%
tesla_data.reset_index(inplace=True)
tesla_data.head(5)
# Out:
#                        Date        Open        High         Low       Close  \
# 0 2022-02-15 00:00:00-05:00  300.000000  307.666656  297.793335  307.476654
# 1 2022-02-16 00:00:00-05:00  304.683319  308.809998  300.403320  307.796661
# 2 2022-02-17 00:00:00-05:00  304.420013  306.166656  291.366669  292.116669
# 3 2022-02-18 00:00:00-05:00  295.333344  295.623322  279.203339  285.660004
# 4 2022-02-22 00:00:00-05:00  278.043335  285.576660  267.033325  273.843323
#
#      Volume  Dividends  Stock Splits
# 0  57286200        0.0           0.0
# 1  51294300        0.0           0.0
# 2  55178400        0.0           0.0
# 3  68501700        0.0           0.0
# 4  83288100        0.0           0.0

# %% [markdown]
# ## Question 2: Use Webscraping to Extract Tesla Revenue Data

# %% [markdown]
# Use the `requests` library to download the webpage https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/revenue.htm Save the text of the response as a variable named `html_data`.

# %%
import requests
import pandas as pd
import bs4 as BeautifulSoup

url= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/revenue.htm"
html_data = requests.get(url).text

# %% [markdown]
# Parse the html data using `beautiful_soup`.

# %%
soup = BeautifulSoup.BeautifulSoup(html_data, 'html5lib')

# %% [markdown]
# Using `BeautifulSoup` or the `read_html` function extract the table with `Tesla Quarterly Revenue` and store it into a dataframe named `tesla_revenue`. The dataframe should have columns `Date` and `Revenue`.

# %% [markdown]
# <details><summary>Click here if you need help locating the table</summary>
#
# ```
#
# Below is the code to isolate the table, you will now need to loop through the rows and columns like in the previous lab
#
# soup.find_all("tbody")[1]
#
# If you want to use the read_html function the table is located at index 1
#
#
# ```
#
# </details>

# %%
## Store the table into a dataframe
#read_html_tesla_revenue = pd.read_html(url)
#tesla_revenue=read_html_tesla_revenue[1]
#tesla_revenue.head("Date", "Revenue")
#tesla_revenue['Tesla Quarterly Revenue (Millions of US $)', Date , column= 'Revenue']
#tesla_revenue["Date", "Revenue"]

tesla_revenue = pd.read_html(url, match = "Tesla Quarterly Revenue", flavor='bs4')[0]
#print("Dataframe columns: ", tesla_revenue.columns)
tesla_revenue = tesla_revenue.rename(columns={tesla_revenue.columns[0]:'Date', tesla_revenue.columns[1] : 'Revenue'})

tesla_revenue.head()
# Out:
#          Date  Revenue
# 0  2022-09-30  $21,454
# 1  2022-06-30  $16,934
# 2  2022-03-31  $18,756
# 3  2021-12-31  $17,719
# 4  2021-09-30  $13,757

# %% [markdown]
# Execute the following line to remove the comma and dollar sign from the `Revenue` column.

# %%
tesla_revenue["Revenue"] = tesla_revenue['Revenue'].str.replace(',|\$',"") 
tesla_revenue.head()
# Out:
# C:\Users\abdullah.warraich\AppData\Local\Temp\ipykernel_18600\480329323.py:1: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#          Date Revenue
# 0  2022-09-30   21454
# 1  2022-06-30   16934
# 2  2022-03-31   18756
# 3  2021-12-31   17719
# 4  2021-09-30   13757

# %% [markdown]
# Execute the following lines to remove an null or empty strings in the Revenue column.

# %%
tesla_revenue.dropna(inplace=True)

tesla_revenue = tesla_revenue[tesla_revenue['Revenue'] != ""]

# %% [markdown]
# Display the last 5 row of the `tesla_revenue` dataframe using the `tail` function. Take a screenshot of the results.

# %%
tesla_revenue.tail()
# Out:
#           Date Revenue
# 48  2010-09-30      31
# 49  2010-06-30      28
# 50  2010-03-31      21
# 52  2009-09-30      46
# 53  2009-06-30      27

# %% [markdown]
# ## Question 3: Use yfinance to Extract Stock Data

# %% [markdown]
# Using the `Ticker` function enter the ticker symbol of the stock we want to extract data on to create a ticker object. The stock is GameStop and its ticker symbol is `GME`.

# %%
import yfinance as yf
import pandas as pd

GameStop= yf.Ticker("GME")

# %% [markdown]
# Using the ticker object and the function `history` extract stock information and save it in a dataframe named `gme_data`. Set the `period` parameter to `max` so we get information for the maximum amount of time.

# %%
gme_data= GameStop.history(period="max")
gme_data= gme_data.astype({col: str for col in gme_data.columns})
gme_data.head()
# Out:
#                                          Open                High  \
# Date
# 2002-02-13 00:00:00-05:00  1.6201287749133175  1.6933502499180326
# 2002-02-14 00:00:00-05:00  1.7127070992374456   1.716073516140932
# 2002-02-15 00:00:00-05:00  1.6832504163818822  1.6874584782119293
# 2002-02-19 00:00:00-05:00  1.6664180429782811  1.6664180429782811
# 2002-02-20 00:00:00-05:00  1.6159204280113415  1.6622097492218018
#
#                                           Low               Close    Volume  \
# Date
# 2002-02-13 00:00:00-05:00   1.603296203950054  1.6916669607162476  76216000
# 2002-02-14 00:00:00-05:00  1.6706258445167577  1.6832501888275146  11021600
# 2002-02-15 00:00:00-05:00  1.6580017243470615   1.674834132194519   8389600
# 2002-02-19 00:00:00-05:00  1.5780474499897692  1.6075043678283691   7410400
# 2002-02-20 00:00:00-05:00  1.6032959217473381  1.6622097492218018   6892800
#
#                           Dividends Stock Splits
# Date
# 2002-02-13 00:00:00-05:00       0.0          0.0
# 2002-02-14 00:00:00-05:00       0.0          0.0
# 2002-02-15 00:00:00-05:00       0.0          0.0
# 2002-02-19 00:00:00-05:00       0.0          0.0
# 2002-02-20 00:00:00-05:00       0.0          0.0

# %% [markdown]
# **Reset the index** using the `reset_index(inplace=True)` function on the gme_data DataFrame and display the first five rows of the `gme_data` dataframe using the `head` function. Take a screenshot of the results and code from the beginning of Question 3 to the results below.

# %%
gme_data.reset_index(inplace=True)
gme_data.head(5)
# Out:
#                        Date                Open                High  \
# 0 2002-02-13 00:00:00-05:00  1.6201287749133175  1.6933502499180326
# 1 2002-02-14 00:00:00-05:00  1.7127070992374456   1.716073516140932
# 2 2002-02-15 00:00:00-05:00  1.6832504163818822  1.6874584782119293
# 3 2002-02-19 00:00:00-05:00  1.6664180429782811  1.6664180429782811
# 4 2002-02-20 00:00:00-05:00  1.6159204280113415  1.6622097492218018
#
#                   Low               Close    Volume Dividends Stock Splits
# 0   1.603296203950054  1.6916669607162476  76216000       0.0          0.0
# 1  1.6706258445167577  1.6832501888275146  11021600       0.0          0.0
# 2  1.6580017243470615   1.674834132194519   8389600       0.0          0.0
# 3  1.5780474499897692  1.6075043678283691   7410400       0.0          0.0
# 4  1.6032959217473381  1.6622097492218018   6892800       0.0          0.0

# %% [markdown]
# ## Question 4: Use Webscraping to Extract GME Revenue Data

# %% [markdown]
# Use the `requests` library to download the webpage https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/stock.html. Save the text of the response as a variable named `html_data`.

# %%
import requests
import bs4 as BeautifulSoup
import pandas as pd

url = requests.get("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/stock.html")

html_data = url.text

# %%
# !mamba install bs4==4.10.0 
# !mamba install html5lib==1.1 
# !pip install lxml==4.9.1
# Out:
# 0 examples ran in 0.0000 seconds
#
#
# 0 examples ran in 0.0000 seconds
# Requirement already satisfied: lxml==4.9.1 in c:\users\abdullah.warraich\appdata\local\programs\python\python310\lib\site-packages (4.9.1)

# %% [markdown]
# Parse the html data using `beautiful_soup`.

# %%
soup=BeautifulSoup.BeautifulSoup(html_data, "html5lib")

# %% [markdown]
# Using `BeautifulSoup` or the `read_html` function extract the table with `GameStop Quarterly Revenue` and store it into a dataframe named `gme_revenue`. The dataframe should have columns `Date` and `Revenue`. Make sure the comma and dollar sign is removed from the `Revenue` column using a method similar to what you did in Question 2.

# %% [markdown]
# <details><summary>Click here if you need help locating the table</summary>
#
# ```
#
# Below is the code to isolate the table, you will now need to loop through the rows and columns like in the previous lab
#
# soup.find_all("tbody")[1]
#
# If you want to use the read_html function the table is located at index 1
#
#
# ```
#
# </details>

# %%
gme_revenue_str = pd.read_html(str(soup))
gme_revenue=gme_revenue_str[0]
gme_revenue = gme_revenue.rename(columns={gme_revenue.columns[0]:'Date', gme_revenue.columns[1] : 'Revenue'})

gme_revenue["Revenue"] = gme_revenue['Revenue'].str.replace(',|\$',"") 

gme_revenue.dropna(inplace=True)
gme_revenue = gme_revenue[gme_revenue['Revenue'] != ""]

gme_revenue= gme_revenue.astype({col: str for col in gme_revenue.columns})

gme_revenue.head()
#type(gme_revenue)
# Out:
# C:\Users\abdullah.warraich\AppData\Local\Temp\ipykernel_18600\1176173363.py:5: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#    Date Revenue
# 0  2020    6466
# 1  2019    8285
# 2  2018    8547
# 3  2017    7965
# 4  2016    9364

# %% [markdown]
# Display the last five rows of the `gme_revenue` dataframe using the `tail` function. Take a screenshot of the results.

# %%
gme_revenue.tail(5)
# Out:
#     Date Revenue
# 11  2009    8806
# 12  2008    7094
# 13  2007    5319
# 14  2006    3092
# 15  2005    1843

# %% [markdown]
# ## Question 5: Plot Tesla Stock Graph

# %% [markdown]
# Use the `make_graph` function to graph the Tesla Stock Data, also provide a title for the graph. The structure to call the `make_graph` function is `make_graph(tesla_data, tesla_revenue, 'Tesla')`. Note the graph will only show data upto June 2021.

# %%
make_graph(tesla_data, tesla_revenue, 'Tesla')

# %% [markdown]
# ## Question 6: Plot GameStop Stock Graph

# %% [markdown]
# Use the `make_graph` function to graph the GameStop Stock Data, also provide a title for the graph. The structure to call the `make_graph` function is `make_graph(gme_data, gme_revenue, 'GameStop')`. Note the graph will only show data upto June 2021.

# %%
make_graph(gme_data, gme_revenue, 'GameStop')

#gme_data.columns[0]

# %% [markdown]
# <h2>About the Authors:</h2>
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0220ENSkillsNetwork900-2022-01-01">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.
#
# Azim Hirjani

# %% [markdown]
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By    | Change Description        |
# | ----------------- | ------- | ------------- | ------------------------- |
# | 2022-02-28        | 1.2     | Lakshmi Holla | Changed the URL of GameStop |
# | 2020-11-10        | 1.1     | Malika Singla | Deleted the Optional part |
# | 2020-08-27        | 1.0     | Malika Singla | Added lab to GitLab       |
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
#
# <p>
